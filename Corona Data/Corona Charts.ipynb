# %%
import pandas as pd
from pandas import DataFrame as df
import numpy as np
import datetime

# %%
from matplotlib import pyplot as plt

# %%
from matplotlib import dates as mdates

# %%
us = pd.read_csv('us.csv')

# %%
states = pd.read_csv('us-states.csv')

# %%
counties = pd.read_csv('us-counties.csv')

# %%
us
# Out:
#            date    cases  deaths
# 0    2020-01-21        1       0
# 1    2020-01-22        1       0
# 2    2020-01-23        1       0
# 3    2020-01-24        2       0
# 4    2020-01-25        3       0
# ..          ...      ...     ...
# 176  2020-07-15  3513850  137327
# 177  2020-07-16  3589493  138284
# 178  2020-07-17  3660324  139186
# 179  2020-07-18  3722722  139961
# 180  2020-07-19  3784920  140373
#
# [181 rows x 3 columns]

# %%
fig, ax = plt.subplots(1,1)
ax.plot(us.cases / 1000)
plt.title('US Coronavirus cases from 01/21/20-07/19/20')
plt.ylabel('thousands of cases')
plt.xlabel('days since first case')


plt.show()

# %%
states
# Out:
#             date          state  fips  cases  deaths
# 0     2020-01-21     Washington    53      1       0
# 1     2020-01-22     Washington    53      1       0
# 2     2020-01-23     Washington    53      1       0
# 3     2020-01-24       Illinois    17      1       0
# 4     2020-01-24     Washington    53      1       0
# ...          ...            ...   ...    ...     ...
# 7654  2020-07-19       Virginia    51  77430    2027
# 7655  2020-07-19     Washington    53  48601    1512
# 7656  2020-07-19  West Virginia    54   5042     100
# 7657  2020-07-19      Wisconsin    55  45953     853
# 7658  2020-07-19        Wyoming    56   2126      24
#
# [7659 rows x 5 columns]

# %%
ny = states[states.state == 'New York']
ny
# Out:
#             date     state  fips   cases  deaths
# 246   2020-03-01  New York    36       1       0
# 261   2020-03-02  New York    36       1       0
# 276   2020-03-03  New York    36       2       0
# 293   2020-03-04  New York    36      11       0
# 313   2020-03-05  New York    36      22       0
# ...          ...       ...   ...     ...     ...
# 7417  2020-07-15  New York    36  408709   32115
# 7472  2020-07-16  New York    36  409476   32133
# 7527  2020-07-17  New York    36  410254   32147
# 7582  2020-07-18  New York    36  411006   32167
# 7637  2020-07-19  New York    36  411515   32187
#
# [141 rows x 5 columns]

# %%
nym = ny.reset_index(drop = True)
nym
# Out:
#            date     state  fips   cases  deaths
# 0    2020-03-01  New York    36       1       0
# 1    2020-03-02  New York    36       1       0
# 2    2020-03-03  New York    36       2       0
# 3    2020-03-04  New York    36      11       0
# 4    2020-03-05  New York    36      22       0
# ..          ...       ...   ...     ...     ...
# 136  2020-07-15  New York    36  408709   32115
# 137  2020-07-16  New York    36  409476   32133
# 138  2020-07-17  New York    36  410254   32147
# 139  2020-07-18  New York    36  411006   32167
# 140  2020-07-19  New York    36  411515   32187
#
# [141 rows x 5 columns]

# %%
fig, ax = plt.subplots(1,1)
ax.plot(nym.cases / 1000)
plt.title('NY cases from 03/01/20-07/19/20')
plt.ylabel('thousands of cases')
plt.xlabel('days since first case')

plt.show()

# %%
nc = counties[(counties.county == 'Nassau') & (counties.state == 'New York')]
nassau = nc.reset_index(drop = True)
nassau
# Out:
#            date  county     state     fips  cases  deaths
# 0    2020-03-05  Nassau  New York  36059.0      1       0
# 1    2020-03-06  Nassau  New York  36059.0      4       0
# 2    2020-03-07  Nassau  New York  36059.0      4       0
# 3    2020-03-08  Nassau  New York  36059.0      5       0
# 4    2020-03-09  Nassau  New York  36059.0     17       0
# ..          ...     ...       ...      ...    ...     ...
# 132  2020-07-15  Nassau  New York  36059.0  42462    2702
# 133  2020-07-16  Nassau  New York  36059.0  42506    2704
# 134  2020-07-17  Nassau  New York  36059.0  42555    2704
# 135  2020-07-18  Nassau  New York  36059.0  42594    2704
# 136  2020-07-19  Nassau  New York  36059.0  42622    2704
#
# [137 rows x 6 columns]

# %%
fig, ax = plt.subplots(1,1)
ax.plot(nassau.cases / 1000)
plt.title('Nassau County cases from 03/05/20-07/19/20')
plt.ylabel('thousands of cases')
plt.xlabel('days since first case')
# Out:
# Text(0.5, 0, 'days since first case')

# %%
florida = states[states.state == 'Florida']
fl = florida.reset_index(drop=True)
fl
# Out:
#            date    state  fips   cases  deaths
# 0    2020-03-01  Florida    12       2       0
# 1    2020-03-02  Florida    12       2       0
# 2    2020-03-03  Florida    12       3       0
# 3    2020-03-04  Florida    12       3       0
# 4    2020-03-05  Florida    12       4       0
# ..          ...      ...   ...     ...     ...
# 136  2020-07-15  Florida    12  301802    4520
# 137  2020-07-16  Florida    12  315767    4676
# 138  2020-07-17  Florida    12  327233    4804
# 139  2020-07-18  Florida    12  337561    4894
# 140  2020-07-19  Florida    12  350039    4981
#
# [141 rows x 5 columns]

# %%
cal = states[states.state == 'California']
cal = cal.reset_index(drop = True)
cal
# Out:
#            date       state  fips   cases  deaths
# 0    2020-01-25  California     6       1       0
# 1    2020-01-26  California     6       2       0
# 2    2020-01-27  California     6       2       0
# 3    2020-01-28  California     6       2       0
# 4    2020-01-29  California     6       2       0
# ..          ...         ...   ...     ...     ...
# 172  2020-07-15  California     6  355497    7368
# 173  2020-07-16  California     6  364761    7490
# 174  2020-07-17  California     6  374922    7607
# 175  2020-07-18  California     6  383194    7697
# 176  2020-07-19  California     6  391460    7710
#
# [177 rows x 5 columns]

# %%
tex = states[states.state == 'Texas']
tex = tex.reset_index(drop = True)
tex
# Out:
#            date  state  fips   cases  deaths
# 0    2020-02-12  Texas    48       1       0
# 1    2020-02-13  Texas    48       2       0
# 2    2020-02-14  Texas    48       2       0
# 3    2020-02-15  Texas    48       2       0
# 4    2020-02-16  Texas    48       2       0
# ..          ...    ...   ...     ...     ...
# 154  2020-07-15  Texas    48  296478    3590
# 155  2020-07-16  Texas    48  311516    3744
# 156  2020-07-17  Texas    48  321242    3889
# 157  2020-07-18  Texas    48  330059    3972
# 158  2020-07-19  Texas    48  338036    4033
#
# [159 rows x 5 columns]

# %%
fig, ax = plt.subplots(1,1)
ax.plot(nym.cases/1000)
ax.plot(fl.cases / 1000)
plt.title('total cases from first reported case-07/19/20')
plt.ylabel('thousands of cases')
plt.xlabel('days since first case')
plt.legend(['New York','Florida'])

# %%
present = states[states.date == '2020-07-19']
present
# Out:
#             date                     state  fips   cases  deaths
# 7604  2020-07-19                   Alabama     1   67011    1287
# 7605  2020-07-19                    Alaska     2    2275      16
# 7606  2020-07-19                   Arizona     4  143644    2768
# 7607  2020-07-19                  Arkansas     5   33228     357
# 7608  2020-07-19                California     6  391460    7710
# 7609  2020-07-19                  Colorado     8   40182    1753
# 7610  2020-07-19               Connecticut     9   47893    4396
# 7611  2020-07-19                  Delaware    10   13519     523
# 7612  2020-07-19      District of Columbia    11   11261     578
# 7613  2020-07-19                   Florida    12  350039    4981
# 7614  2020-07-19                   Georgia    13  130794    3110
# 7615  2020-07-19                      Guam    66    1284       6
# 7616  2020-07-19                    Hawaii    15    1359      23
# ...

# %%
present_states = present.drop([present.index[56],present.index[55],present.index[49],present.index[41],present.index[36],present.index[8],present.index[11]])

present_states
# Out:
#           date           state  fips   cases  deaths
# 0   2020-07-19         Alabama   1.0   67011    1287
# 1   2020-07-19          Alaska   2.0    2275      16
# 2   2020-07-19         Arizona   4.0  143644    2768
# 3   2020-07-19        Arkansas   5.0   33228     357
# 4   2020-07-19      California   6.0  391460    7710
# 5   2020-07-19        Colorado   8.0   40182    1753
# 6   2020-07-19     Connecticut   9.0   47893    4396
# 7   2020-07-19        Delaware  10.0   13519     523
# 9   2020-07-19         Florida  12.0  350039    4981
# 10  2020-07-19         Georgia  13.0  130794    3110
# 12  2020-07-19          Hawaii  15.0    1359      23
# 13  2020-07-19           Idaho  16.0   14960     120
# 14  2020-07-19        Illinois  17.0  162963    7491
# 15  2020-07-19         Indiana  18.0   57965    2822
# 16  2020-07-19            Iowa  19.0   38813     793
# 17  2020-07-19          Kansas  20.0   22459     313
# 18  2020-07-19        Kentucky  21.0   23600     691
# ...

# %%
states_only =present_states.reset_index(drop=True)
states_only
# Out:
#           date           state  fips   cases  deaths
# 0   2020-07-19         Alabama   1.0   67011    1287
# 1   2020-07-19          Alaska   2.0    2275      16
# 2   2020-07-19         Arizona   4.0  143644    2768
# 3   2020-07-19        Arkansas   5.0   33228     357
# 4   2020-07-19      California   6.0  391460    7710
# 5   2020-07-19        Colorado   8.0   40182    1753
# 6   2020-07-19     Connecticut   9.0   47893    4396
# 7   2020-07-19        Delaware  10.0   13519     523
# 8   2020-07-19         Florida  12.0  350039    4981
# 9   2020-07-19         Georgia  13.0  130794    3110
# 10  2020-07-19          Hawaii  15.0    1359      23
# 11  2020-07-19           Idaho  16.0   14960     120
# 12  2020-07-19        Illinois  17.0  162963    7491
# 13  2020-07-19         Indiana  18.0   57965    2822
# 14  2020-07-19            Iowa  19.0   38813     793
# 15  2020-07-19          Kansas  20.0   22459     313
# 16  2020-07-19        Kentucky  21.0   23600     691
# ...

# %%
less = present[present.cases < 70000]
more = present[present.cases > 70000]
more
# Out:
#           date           state  fips   cases  deaths
# 2   2020-07-19         Arizona   4.0  143644    2768
# 4   2020-07-19      California   6.0  391460    7710
# 9   2020-07-19         Florida  12.0  350039    4981
# 10  2020-07-19         Georgia  13.0  130794    3110
# 14  2020-07-19        Illinois  17.0  162963    7491
# 19  2020-07-19       Louisiana  22.0   91816    3543
# 21  2020-07-19        Maryland  24.0   78698    3377
# 22  2020-07-19   Massachusetts  25.0  113534    8431
# 23  2020-07-19        Michigan  26.0   81935    6369
# 31  2020-07-19      New Jersey  34.0  178757   15706
# 33  2020-07-19        New York  36.0  411515   32187
# 34  2020-07-19  North Carolina  37.0   99956    1661
# 37  2020-07-19            Ohio  39.0   74932    3174
# 40  2020-07-19    Pennsylvania  42.0  105384    7074
# 45  2020-07-19       Tennessee  47.0   76180     834
# 46  2020-07-19           Texas  48.0  338036    4033
# 50  2020-07-19        Virginia  51.0   77430    2027

# %%
other_cases = sum(less.cases)
other_deaths = sum(less.deaths)
other_deaths
# Out:
# 27895

# %%
other_row = {'state': 'Other', 'cases': other_cases, 'deaths': other_deaths}
more_other = more.append(other_row,ignore_index=True)
more_other
# Out:
#           date           state  fips   cases  deaths
# 0   2020-07-19         Arizona   4.0  143644    2768
# 1   2020-07-19      California   6.0  391460    7710
# 2   2020-07-19         Florida  12.0  350039    4981
# 3   2020-07-19         Georgia  13.0  130794    3110
# 4   2020-07-19        Illinois  17.0  162963    7491
# 5   2020-07-19       Louisiana  22.0   91816    3543
# 6   2020-07-19        Maryland  24.0   78698    3377
# 7   2020-07-19   Massachusetts  25.0  113534    8431
# 8   2020-07-19        Michigan  26.0   81935    6369
# 9   2020-07-19      New Jersey  34.0  178757   15706
# 10  2020-07-19        New York  36.0  411515   32187
# 11  2020-07-19  North Carolina  37.0   99956    1661
# 12  2020-07-19            Ohio  39.0   74932    3174
# 13  2020-07-19    Pennsylvania  42.0  105384    7074
# 14  2020-07-19       Tennessee  47.0   76180     834
# 15  2020-07-19           Texas  48.0  338036    4033
# 16  2020-07-19        Virginia  51.0   77430    2027
# ...

# %%
population = pd.read_csv('population.csv')
population
# Out:
#     SUMLEV REGION DIVISION  STATE                      NAME  POPESTIMATE2019  \
# 0       10      0        0      0             United States        328239523
# 1       40      3        6      1                   Alabama          4903185
# 2       40      4        9      2                    Alaska           731545
# 3       40      4        8      4                   Arizona          7278717
# 4       40      3        7      5                  Arkansas          3017804
# 5       40      4        9      6                California         39512223
# 6       40      4        8      8                  Colorado          5758736
# 7       40      1        1      9               Connecticut          3565287
# 8       40      3        5     10                  Delaware           973764
# 9       40      3        5     11      District of Columbia           705749
# 10      40      3        5     12                   Florida         21477737
# ...

# %%
population_states = population.drop([population.index[0],population.index[9],population.index[52]])
population_states
# Out:
#     SUMLEV REGION DIVISION  STATE            NAME  POPESTIMATE2019  \
# 1       40      3        6      1         Alabama          4903185
# 2       40      4        9      2          Alaska           731545
# 3       40      4        8      4         Arizona          7278717
# 4       40      3        7      5        Arkansas          3017804
# 5       40      4        9      6      California         39512223
# 6       40      4        8      8        Colorado          5758736
# 7       40      1        1      9     Connecticut          3565287
# 8       40      3        5     10        Delaware           973764
# 10      40      3        5     12         Florida         21477737
# 11      40      3        5     13         Georgia         10617423
# 12      40      4        9     15          Hawaii          1415872
# 13      40      4        8     16           Idaho          1787065
# 14      40      2        3     17        Illinois         12671821
# ...

# %%
population_states = population_states.reset_index(drop=True)
population_states
# Out:
#     SUMLEV REGION DIVISION  STATE            NAME  POPESTIMATE2019  \
# 0       40      3        6      1         Alabama          4903185
# 1       40      4        9      2          Alaska           731545
# 2       40      4        8      4         Arizona          7278717
# 3       40      3        7      5        Arkansas          3017804
# 4       40      4        9      6      California         39512223
# 5       40      4        8      8        Colorado          5758736
# 6       40      1        1      9     Connecticut          3565287
# 7       40      3        5     10        Delaware           973764
# 8       40      3        5     12         Florida         21477737
# 9       40      3        5     13         Georgia         10617423
# 10      40      4        9     15          Hawaii          1415872
# 11      40      4        8     16           Idaho          1787065
# 12      40      2        3     17        Illinois         12671821
# ...

# %%
plt.pie(more_other.cases,labels=more_other.state)
plt.title('Spread of Total US Cases as of 07/19/20')
# Out:
# Text(0.5, 1.0, 'Spread of Total US Cases as of 07/19/20')

# %%
plt.scatter(population_states.POPESTIMATE2019,states_only.cases)
plt.subplots_adjust(right = 2)

# %%
plt.subplot(2,2,1)
plt.plot(us.cases / 1000)
plt.plot(us.deaths/ 1000)
plt.title('US Coronavirus cases and deaths from 01/21/20-07/19/20')
plt.ylabel('thousands of cases/deaths')
plt.xlabel('days since first case')
plt.legend(['cases','deaths'])

plt.subplot(2,2,2)
plt.pie(more_other.cases,labels=more_other.state)
plt.title('Spread of Total US Cases as of 07/19/20')

plt.subplot(2,2,3)
pl = plt.scatter(population_states.POPESTIMATE2019/1000000,states_only.cases/1000)
plt.title('Coronavirus Cases VS Population')
plt.xlabel('population(millions)')
plt.ylabel('thousands of cases')

plt.subplot(2,2,4)
plt.plot(nym.cases/1000)
plt.plot(fl.cases/1000)
plt.plot(cal.cases/1000)
plt.plot(tex.cases/1000)
plt.title('US Coronavirus cases by state from date of first case until 07/19/20')
plt.ylabel('thousands of cases')
plt.xlabel('days since first case')
plt.legend(['New York','Florida','California','Texas'])

plt.subplots_adjust(right = 2)
plt.subplots_adjust(top = 2)



plt.show()
